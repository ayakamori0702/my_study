# %%
import pandas as pd
import requests

# %% [markdown]
# # データの取得

# %%
URL = "https://finance.yahoo.com/quote/AAPL/history?p=AAPL"

# %%
data = pd.read_html(requests.get(URL,headers={"User-agent" : "Mozilla/5.0"}).text,header = 0)

# %%
data[0].head() #今回表は一つだけなので０
# Out:
#            Date    Open    High     Low  Close* Adj Close**    Volume
# 0  Mar 04, 2022  164.49  165.55  162.11  163.17      163.17  83819592
# 1  Mar 03, 2022  168.47  168.91  165.55  166.23      166.23  76335600
# 2  Mar 02, 2022  164.39  167.36  162.95  166.56      166.56  79724800
# 3  Mar 01, 2022  164.70  166.60  161.97  163.20      163.20  83474400
# 4  Feb 28, 2022  163.06  165.42  162.43  165.12      165.12  94869100

# %%
data[0].tail()
# Out:
#                                                   Date  \
# 96                                        Oct 19, 2021
# 97                                        Oct 18, 2021
# 98                                        Oct 15, 2021
# 99                                        Oct 14, 2021
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 96                                              147.01
# 97                                              143.45
# 98                                              143.77
# 99                                              142.11
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 96                                              149.17
# 97                                              146.84
# 98                                              144.90
# 99                                              143.88
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 96                                              146.55
# 97                                              143.16
# 98                                              143.51
# 99                                              141.51
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 96                                              148.76
# 97                                              146.55
# 98                                              144.84
# 99                                              143.76
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 96                                              148.35
# 97                                              146.15
# 98                                              144.44
# 99                                              143.37
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 96                                            76378900
# 97                                            85589200
# 98                                            67885200
# 99                                            69907100
# 100  *Close price adjusted for splits.**Adjusted cl...

# %% [markdown]
# # 前処理

# %% [markdown]
# ### 取得データの問題点
# *["Adj Close**"]文字列が入り込んでいる
# *[Date]の日付が文字列　→　時系列グラフに変換できない

# %%
data[0]["Adj Close**"] = pd.to_numeric(data[0]["Adj Close**"],errors = "coerce")

# %%
data[0].tail()
# Out:
#                     Date    Open    High     Low  Close*  Adj Close**  \
# Date2
# 2021-10-20  Oct 20, 2021  148.70  149.75  148.12  149.26       148.85
# 2021-10-19  Oct 19, 2021  147.01  149.17  146.55  148.76       148.35
# 2021-10-18  Oct 18, 2021  143.45  146.84  143.16  146.55       146.15
# 2021-10-15  Oct 15, 2021  143.77  144.90  143.51  144.84       144.44
# 2021-10-14  Oct 14, 2021  142.11  143.88  141.51  143.76       143.37
#
#               Volume
# Date2
# 2021-10-20  58418800
# 2021-10-19  76378900
# 2021-10-18  85589200
# 2021-10-15  67885200
# 2021-10-14  69907100

# %%
data[0].dropna(inplace=True) #inplaceで実行結果を上書き

# %%
data[0].tail()
# Out:
#                     Date    Open    High     Low  Close*  Adj Close**  \
# Date2
# 2021-10-20  Oct 20, 2021  148.70  149.75  148.12  149.26       148.85
# 2021-10-19  Oct 19, 2021  147.01  149.17  146.55  148.76       148.35
# 2021-10-18  Oct 18, 2021  143.45  146.84  143.16  146.55       146.15
# 2021-10-15  Oct 15, 2021  143.77  144.90  143.51  144.84       144.44
# 2021-10-14  Oct 14, 2021  142.11  143.88  141.51  143.76       143.37
#
#               Volume
# Date2
# 2021-10-20  58418800
# 2021-10-19  76378900
# 2021-10-18  85589200
# 2021-10-15  67885200
# 2021-10-14  69907100

# %%
data[0]["Adj Close**"].dtype  # データ型の確認
# Out:
# dtype('float64')

# %%
from datetime import datetime as dt

# %%
data[0]["Date2"] = [dt.strptime(i,"%b %d, %Y") for i in data[0]["Date"]]

# %%
data[0].head()
# Out:
#                     Date    Open    High     Low  Close*  Adj Close**  \
# Date2
# 2022-03-04  Mar 04, 2022  164.49  165.55  162.11  163.17       163.17
# 2022-03-03  Mar 03, 2022  168.47  168.91  165.55  166.23       166.23
# 2022-03-02  Mar 02, 2022  164.39  167.36  162.95  166.56       166.56
# 2022-03-01  Mar 01, 2022  164.70  166.60  161.97  163.20       163.20
# 2022-02-28  Feb 28, 2022  163.06  165.42  162.43  165.12       165.12
#
#               Volume      Date2
# Date2
# 2022-03-04  83819592 2022-03-04
# 2022-03-03  76335600 2022-03-03
# 2022-03-02  79724800 2022-03-02
# 2022-03-01  83474400 2022-03-01
# 2022-02-28  94869100 2022-02-28

# %%
data[0].set_index("Date2",inplace = True)  # インデックスを日付に変更

# %%
data[0].head()
# Out:
#                     Date    Open    High     Low  Close*  Adj Close**  \
# Date2
# 2022-03-04  Mar 04, 2022  164.49  165.55  162.11  163.17       163.17
# 2022-03-03  Mar 03, 2022  168.47  168.91  165.55  166.23       166.23
# 2022-03-02  Mar 02, 2022  164.39  167.36  162.95  166.56       166.56
# 2022-03-01  Mar 01, 2022  164.70  166.60  161.97  163.20       163.20
# 2022-02-28  Feb 28, 2022  163.06  165.42  162.43  165.12       165.12
#
#               Volume
# Date2
# 2022-03-04  83819592
# 2022-03-03  76335600
# 2022-03-02  79724800
# 2022-03-01  83474400
# 2022-02-28  94869100

# %% [markdown]
# # グラフ化する

# %%
data[0]["Adj Close**"].plot(title = "AAPL Stock Price",grid = True)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:title={'center':'AAPL Stock Price'}, xlabel='Date2'>

# %% [markdown]
# # CSVファイルに出力する

# %%
data[0].to_csv("AAPL_Stock.csv")
